# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive/pix2pix/"
# Out:
# 001_Pix2Pix_Project.ipynb  002_Loading_Dataset.ipynb  datasets

# %%
project_dir = '/content/drive/My Drive/pix2pix/'

# %%
# !pip install wget

# %%
# import wget

# %%
# url="http://efrosgans.eecs.berkeley.edu/pix2pix/datasets/edges2shoes.tar.gz"
# !wget "http://efrosgans.eecs.berkeley.edu/pix2pix/datasets/edges2shoes.tar.gz" -P "/content/drive/My Drive/pix2pix/datasets"
# !tar -zxvf "/content/drive/My Drive/pix2pix/datasets/edges2shoes.tar.gz" -C "/content/drive/My Drive/pix2pix/datasets/"
# !rm -rf "/content/drive/My Drive/pix2pix/datasets/edges2shoes.tar.gz"
# Out:
# Streaming output truncated to the last 5000 lines.
# edges2shoes/train/46383_AB.jpg
# edges2shoes/train/46384_AB.jpg
# edges2shoes/train/46385_AB.jpg
# edges2shoes/train/46386_AB.jpg
# edges2shoes/train/46387_AB.jpg
# edges2shoes/train/46388_AB.jpg
# edges2shoes/train/46389_AB.jpg
# edges2shoes/train/4638_AB.jpg
# edges2shoes/train/46390_AB.jpg
# edges2shoes/train/46391_AB.jpg
# edges2shoes/train/46392_AB.jpg
# edges2shoes/train/449_AB.jpg
# edges2shoes/train/44_AB.jpg
# edges2shoes/train/45000_AB.jpg
# edges2shoes/train/45001_AB.jpg
# edges2shoes/train/45002_AB.jpg
# edges2shoes/train/45003_AB.jpg
# edges2shoes/train/45004_AB.jpg
# edges2shoes/train/45005_AB.jpg
# edges2shoes/train/45006_AB.jpg
# edges2shoes/train/45007_AB.jpg
# edges2shoes/train/45008_AB.jpg
# edges2shoes/train/45009_AB.jpg
# edges2shoes/train/4500_AB.jpg
# edges2shoes/train/45010_AB.jpg
# edges2shoes/train/45011_AB.jpg
# edges2shoes/train/45012_AB.jpg
# edges2shoes/train/45013_AB.jpg
# ...

# %%
# !ls "/content/drive/My Drive/pix2pix/datasets/edges2shoes/val/"
# Out:
# 100_AB.jpg  127_AB.jpg	153_AB.jpg  17_AB.jpg	24_AB.jpg  50_AB.jpg  77_AB.jpg
# 101_AB.jpg  128_AB.jpg	154_AB.jpg  180_AB.jpg	25_AB.jpg  51_AB.jpg  78_AB.jpg
# 102_AB.jpg  129_AB.jpg	155_AB.jpg  181_AB.jpg	26_AB.jpg  52_AB.jpg  79_AB.jpg
# 103_AB.jpg  12_AB.jpg	156_AB.jpg  182_AB.jpg	27_AB.jpg  53_AB.jpg  7_AB.jpg
# 104_AB.jpg  130_AB.jpg	157_AB.jpg  183_AB.jpg	28_AB.jpg  54_AB.jpg  80_AB.jpg
# 105_AB.jpg  131_AB.jpg	158_AB.jpg  184_AB.jpg	29_AB.jpg  55_AB.jpg  81_AB.jpg
# 106_AB.jpg  132_AB.jpg	159_AB.jpg  185_AB.jpg	2_AB.jpg   56_AB.jpg  82_AB.jpg
# 107_AB.jpg  133_AB.jpg	15_AB.jpg   186_AB.jpg	30_AB.jpg  57_AB.jpg  83_AB.jpg
# 108_AB.jpg  134_AB.jpg	160_AB.jpg  187_AB.jpg	31_AB.jpg  58_AB.jpg  84_AB.jpg
# 109_AB.jpg  135_AB.jpg	161_AB.jpg  188_AB.jpg	32_AB.jpg  59_AB.jpg  85_AB.jpg
# 10_AB.jpg   136_AB.jpg	162_AB.jpg  189_AB.jpg	33_AB.jpg  5_AB.jpg   86_AB.jpg
# 110_AB.jpg  137_AB.jpg	163_AB.jpg  18_AB.jpg	34_AB.jpg  60_AB.jpg  87_AB.jpg
# ...

# %%
import os

# %%
files_count = [x for x in os.listdir('/content/drive/My Drive/pix2pix/datasets/edges2shoes/train/')]

print(len(files_count))
# Out:
# 49825

# %%
# !rm -rf "/content/drive/My Drive/pix2pix/datasets/edges2shoes.tar.gz"

# %%
# !ls "/content/drive/My Drive/pix2pix/datasets/"
# Out:
# edges2shoes
